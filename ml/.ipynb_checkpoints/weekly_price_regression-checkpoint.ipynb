# %%
from modeler.modeler import Modeler as m
from database.market import Market
from database.strategy import Strategy
import pandas as pd
from datetime import datetime
from tqdm import tqdm

# %%
market = Market()
strategy = Strategy()

# %%
market.connect()
prices = market.retrieve("prices")
sp5 = market.retrieve("sp500")
market.disconnect()

# %%
prices["date"] = pd.to_datetime(prices["date"])
prices["date"]
prices["year"] = [x.year for x in prices["date"]]
prices["quarter"] = [x.quarter for x in prices["date"]]
prices["week"] = [x.week for x in prices["date"]]

# %%
start = 2011
end = 2021
prices = prices[(prices["year"] >= start) & (prices["year"] <= end)]
weekly_sets = []
number_of_training_weeks = 14
for ticker in tqdm(sp5["Symbol"].unique()):
    ticker_data = prices[prices["ticker"]==ticker]
    weekly = ticker_data.groupby(["year","quarter","week"]).mean().reset_index()
    for i in range(number_of_training_weeks):
        weekly[i] = weekly["adjClose"].shift(1)
    weekly["y"] = weekly["adjClose"].shift(-1)
    weekly.dropna(inplace=True)
    weekly["ticker"] = ticker
    weekly_sets.append(weekly)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 505/505 [01:12<00:00,  6.96it/s]

# %%
data = pd.concat(weekly_sets)
for i in range(14):
    data.rename(columns={i:str(i)},inplace=True)

# %%
# strategy.connect()
# data = strategy.retrieve("weekly_training_data").drop("_id",axis=1,errors="ignore")
# strategy.disconnect()

# %%
quarterly = prices.groupby(["year","quarter","ticker"]).mean().reset_index()
quarterly = quarterly.merge(sp5.rename(columns={"Symbol":"ticker"}),on="ticker",how="left")

# %%
data
# Out:
#        year  quarter  week       close        high        low        open  \
# 1    2011.0      1.0   2.0   87.938000   88.281960   87.23600   87.456000
# 2    2011.0      1.0   3.0   88.357500   88.752500   87.74750   88.152500
# 3    2011.0      1.0   4.0   89.004000   89.940000   88.19200   89.164000
# 4    2011.0      1.0   5.0   87.940000   88.320000   87.52600   87.874000
# 5    2011.0      1.0   6.0   90.260000   90.444000   89.25220   89.478000
# ..      ...      ...   ...         ...         ...        ...         ...
# 524  2021.0      2.0  24.0  115.642000  116.941000  114.47884  116.228000
# 525  2021.0      2.0  25.0  116.510000  117.296000  115.64000  116.414000
# 526  2021.0      2.0  26.0  119.466667  120.028333  117.96000  118.523333
# 527  2021.0      3.0  26.0  120.515000  121.515000  119.85005  120.705000
# 528  2021.0      3.0  27.0  120.342500  120.867500  119.23000  120.257500
#
#            volume    adjClose     adjHigh  ...           6           7  \
# 1    2.735740e+06   66.057622   66.315999  ...   64.977419   64.977419
# 2    2.676150e+06   66.372744   66.669461  ...   66.057622   66.057622
# 3    5.221640e+06   66.858384   67.561493  ...   66.372744   66.372744
# 4    2.992080e+06   66.059124   66.344574  ...   66.858384   66.858384
# 5    3.262740e+06   67.801871   67.940089  ...   66.059124   66.059124
# ..            ...         ...         ...  ...         ...         ...
# 524  1.142362e+06  115.642000  116.941000  ...  118.720000  118.720000
# 525  1.199495e+06  116.510000  117.296000  ...  115.642000  115.642000
# 526  7.880653e+05  119.466667  120.028333  ...  116.510000  116.510000
# 527  4.959345e+05  120.515000  121.515000  ...  119.466667  119.466667
# 528  1.026722e+06  120.342500  120.867500  ...  120.515000  120.515000
#
#               8           9          10          11          12          13  \
# 1     64.977419   64.977419   64.977419   64.977419   64.977419   64.977419
# 2     66.057622   66.057622   66.057622   66.057622   66.057622   66.057622
# 3     66.372744   66.372744   66.372744   66.372744   66.372744   66.372744
# 4     66.858384   66.858384   66.858384   66.858384   66.858384   66.858384
# 5     66.059124   66.059124   66.059124   66.059124   66.059124   66.059124
# ..          ...         ...         ...         ...         ...         ...
# 524  118.720000  118.720000  118.720000  118.720000  118.720000  118.720000
# 525  115.642000  115.642000  115.642000  115.642000  115.642000  115.642000
# 526  116.510000  116.510000  116.510000  116.510000  116.510000  116.510000
# 527  119.466667  119.466667  119.466667  119.466667  119.466667  119.466667
# 528  120.515000  120.515000  120.515000  120.515000  120.515000  120.515000
#
#               y  ticker
# 1     66.372744     MMM
# 2     66.858384     MMM
# 3     66.059124     MMM
# 4     67.801871     MMM
# 5     69.646199     MMM
# ..          ...     ...
# 524  116.510000     XYL
# 525  119.466667     XYL
# 526  120.515000     XYL
# 527  120.342500     XYL
# 528  121.640000     XYL
#
# [271578 rows x 31 columns]

# %%
quarterly["price_category"] = [str(100) if x < 100 else str(500) for x in quarterly["adjClose"]]
quarterly["category"] = quarterly["GICS Sector"] + quarterly["price_category"]

# %%
strategy.connect()
categories = strategy.retrieve("predicted_stock_categories")
strategy.disconnect()

# %%
quarterly["category"].unique()
# Out:
# array(['Health Care100', 'Industrials100', 'Consumer Discretionary100',
#        'Information Technology100', 'Consumer Staples100', 'Utilities100',
#        'Financials100', 'Materials100', 'Real Estate100',
#        'Consumer Discretionary500', 'Energy500',
#        'Communication Services100', nan, 'Health Care500',
#        'Financials500', 'Energy100', 'Information Technology500',
#        'Communication Services500', 'Industrials500', 'Real Estate500',
#        'Consumer Staples500', 'Materials500', 'Utilities500'],
#       dtype=object)

# %%
training_year = 1
weekly_gap = 1
for year in range(2012,2021):
    for quarter in range(1,5):
        quarterly_categories = quarterly[(quarterly["year"]==year) & (quarterly["quarter"]==quarter)]
        for category in quarterly_categories["category"].unique():
            try:
                category_tickers = quarterly_categories[quarterly_categories["category"]==category]["ticker"].unique()
                model_data = data[(data["ticker"].isin(category_tickers))]
                first_index = model_data[(model_data["year"] == year - training_year) & (model_data["quarter"]==quarter)].index.values.tolist()[0]
                last_index = model_data[(model_data["year"] == year) & (model_data["quarter"]==quarter)].index.values.tolist()[0]
                training_data = model_data.iloc[first_index:last_index]
                prediction_data = model_data[(model_data["year"] == year) & (model_data["quarter"]==quarter)]
                X = training_data[[str(x) for x in range(number_of_training_weeks)]]
                y = training_data["y"]
                xgb_models = m.xgb_regression({"X":X,"y":y})
                sk_models = m.sk_regression({"X":X,"y":y})
                sk_models.append(xgb_models)
                models = pd.DataFrame(sk_models)
                model = models.sort_values("score",ascending=False).iloc[0]
                sim = prediction_data
                sim["weekly_price_regression_prediction"] = model["model"].predict(sim[[str(x) for x in range(number_of_training_weeks)]])
                sim["score"] = model["score"].item()
                sim = sim[["year","quarter","week","ticker","weekly_price_regression_prediction","score"]]
                strategy.connect()
                strategy.store("non_financial_sim",sim)
                strategy.disconnect()
            except Exception as e:
                print(year,quarter,category,str(e))
# Out:
# ['A' 'ABC' 'ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BAX' 'BDX' 'BMY'
#  'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'COO' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM'
#  'EW' 'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'JNJ' 'LH'
#  'LLY' 'MCK' 'MDT' 'MRK' 'PFE' 'PKI' 'PRGO' 'REGN' 'RMD' 'STE' 'SYK' 'TFX'
#  'TMO' 'UHS' 'UNH' 'VRTX' 'WAT' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'ROP' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL'
#  'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'MHK' 'NKE' 'NWL' 'ORLY' 'PENN'
#  'PHM' 'POOL' 'PVH' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA'
#  'UAA' 'ULTA' 'VFC' 'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS' 'FISV' 'FLT'
#  'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR' 'KLAC'
#  'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NTAP' 'NVDA'
#  'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL' 'TER' 'TRMB'
#  'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'GS' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RE' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['AMT' 'ARE' 'AVB' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST'
#  'IRM' 'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'PSA' 'REG' 'SBAC' 'SPG' 'UDR' 'VNO'
#  'VTR' 'WELL' 'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'NVR' 'RL']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO' 'NOV'
#  'OKE' 'OXY' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CHTR' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'IPG' 'LUMN'
#  'LYV' 'NFLX' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# []
# ['BIIB' 'BIO' 'ISRG' 'MTD']
# ['BLK']
# ['EQIX' 'ESS']
# ['FFIV' 'IBM']
# ['GOOGL']
# ['GWW']
# ['PXD']
# ['A' 'ABC' 'ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BAX' 'BDX' 'BMY'
#  'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'COO' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM'
#  'EW' 'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'JNJ' 'LH'
#  'LLY' 'MCK' 'MDT' 'MRK' 'PFE' 'PKI' 'PRGO' 'RMD' 'STE' 'SYK' 'TFX' 'TMO'
#  'UHS' 'UNH' 'VRTX' 'WAT' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'ROP' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL'
#  'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'MHK' 'NKE' 'NWL' 'ORLY' 'PENN'
#  'PHM' 'POOL' 'PVH' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA'
#  'UAA' 'ULTA' 'VFC' 'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS' 'FISV' 'FLT'
#  'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR' 'KLAC'
#  'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW' 'NTAP'
#  'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL' 'TER'
#  'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'GS' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RE' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'SPG' 'UDR' 'VNO' 'VTR' 'WELL'
#  'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'NVR' 'RL']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO' 'NOV'
#  'OKE' 'OXY' 'PSX' 'PXD' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CHTR' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN'
#  'LYV' 'NFLX' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA']
# []
# ['BIIB' 'BIO' 'ISRG' 'MTD' 'REGN']
# ['BLK']
# ['FFIV' 'IBM']
# ['GOOGL']
# ['GWW']
# ['A' 'ABC' 'ABMD' 'ABT' 'ALGN' 'AMGN' 'ANTM' 'BAX' 'BDX' 'BMY' 'BSX' 'CAH'
#  'CERN' 'CI' 'CNC' 'COO' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD'
#  'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'JNJ' 'LH' 'LLY' 'MCK'
#  'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS' 'UNH' 'VRTX'
#  'WAT' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'ROP' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL'
#  'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'MHK' 'NKE' 'NWL' 'ORLY' 'PENN'
#  'PHM' 'POOL' 'PVH' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA'
#  'UAA' 'ULTA' 'VFC' 'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS' 'FISV'
#  'FLT' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL'
#  'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'GS' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RE' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'BIIB' 'BIO' 'ISRG' 'MTD' 'PRGO' 'REGN']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'NVR' 'RL']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO' 'NOV'
#  'OKE' 'OXY' 'PSX' 'PXD' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CHTR' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN'
#  'LYV' 'NFLX' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA' 'SPG']
# []
# ['BLK']
# ['GOOGL']
# ['GWW']
# ['IBM']
# ['A' 'ABC' 'ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BAX' 'BDX' 'BMY'
#  'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'COO' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM'
#  'EW' 'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'JNJ' 'LH'
#  'LLY' 'MCK' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS'
#  'UNH' 'VRTX' 'WAT' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL' 'UNP'
#  'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'MHK' 'NKE' 'NWL' 'ORLY' 'PENN'
#  'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA'
#  'ULTA' 'VFC' 'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS' 'FISV'
#  'FLT' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL'
#  'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RE' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'SPG' 'UDR' 'VNO' 'VTR' 'WELL'
#  'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'NVR' 'PVH' 'RL']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CHTR' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN'
#  'LYV' 'NFLX' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA']
# []
# ['BIIB' 'BIO' 'ISRG' 'MTD' 'PRGO' 'REGN']
# ['BLK' 'GS']
# ['GOOGL']
# ['GWW' 'ROP']
# ['IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BAX' 'BDX'
#  'BMY' 'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM'
#  'EW' 'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'JNJ' 'LH'
#  'LLY' 'MCK' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS'
#  'UNH' 'VRTX' 'WAT' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL' 'UNP'
#  'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'ORLY'
#  'PENN' 'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA'
#  'UAA' 'ULTA' 'VFC' 'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS' 'FISV'
#  'FLT' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL'
#  'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['AMT' 'ARE' 'AVB' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST'
#  'IRM' 'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL'
#  'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'PVH' 'RL']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CHTR' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN'
#  'LYV' 'NFLX' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# []
# ['BIIB' 'BIO' 'COO' 'ISRG' 'MTD' 'PRGO' 'REGN']
# ['BLK' 'GS' 'RE']
# ['EQIX' 'ESS' 'PSA' 'SPG']
# ['GOOGL']
# ['GWW' 'ROP']
# ['IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BAX' 'BDX'
#  'BMY' 'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM'
#  'EW' 'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'IQV' 'JNJ'
#  'LH' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS'
#  'UNH' 'VRTX' 'WAT' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL' 'UNP'
#  'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM'
#  'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA' 'ULTA'
#  'VFC' 'WHR']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS'
#  'FISV' 'FLT' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY'
#  'JNPR' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK'
#  'NOW' 'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS'
#  'TEL' 'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'WYNN']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA' 'SPG']
# []
# ['BIIB' 'BIO' 'COO' 'ISRG' 'MCK' 'MTD' 'PRGO' 'REGN']
# ['BLK' 'GS' 'RE']
# ['CHTR' 'GOOGL']
# ['GWW' 'ROP']
# ['IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'AMGN' 'ANTM' 'BAX' 'BDX' 'BMY'
#  'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW'
#  'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'IQV' 'JNJ' 'LH'
#  'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS' 'UNH'
#  'VRTX' 'WST' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'BA' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FDX' 'GD' 'GE' 'GNRC'
#  'HII' 'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LMT'
#  'LUV' 'MAS' 'MMM' 'NLSN' 'NOC' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI'
#  'ROK' 'ROL' 'RSG' 'RTX' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL' 'UNP'
#  'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'KMX' 'LB' 'LEG'
#  'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM'
#  'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA' 'VFC']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS'
#  'FISV' 'FLT' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY'
#  'JNPR' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK'
#  'NOW' 'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS'
#  'TEL' 'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'BIIB' 'BIO' 'COO' 'ISRG' 'MCK' 'MTD' 'PRGO' 'REGN' 'WAT']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'ULTA' 'WHR'
#  'WYNN']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA' 'SPG']
# []
# ['BLK' 'GS' 'RE']
# ['CHTR' 'GOOGL']
# ['GWW' 'ROP']
# ['IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'AMGN' 'ANTM' 'BAX' 'BDX' 'BMY'
#  'BSX' 'CAH' 'CERN' 'CI' 'CNC' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW'
#  'GILD' 'HCA' 'HOLX' 'HSIC' 'HUM' 'IDXX' 'ILMN' 'INCY' 'IQV' 'JNJ' 'LH'
#  'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS' 'UNH'
#  'VRTX' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GD' 'GE' 'GNRC' 'HII'
#  'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN'
#  'NOC' 'NSC' 'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROK' 'ROL' 'RSG' 'RTX' 'SNA'
#  'SWK' 'TDG' 'TDY' 'TT' 'TXT' 'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM'
#  'XYL']
# ['AAP' 'APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB'
#  'LEG' 'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN'
#  'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA'
#  'VFC']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS'
#  'FISV' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL'
#  'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KMB' 'KO'
#  'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ' 'SYY' 'TAP'
#  'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SIVB' 'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MLM' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'BIIB' 'BIO' 'COO' 'ISRG' 'MCK' 'MTD' 'PRGO' 'REGN' 'WAT']
# ['AMT' 'ARE' 'AVB' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST'
#  'IRM' 'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL'
#  'WY']
# ['AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'ULTA' 'WHR'
#  'WYNN']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['BA' 'CMI' 'FDX' 'GWW' 'KSU' 'LMT' 'MMM' 'PH' 'ROP']
# []
# ['BLK' 'GS' 'RE']
# ['CHTR' 'GOOGL']
# ['COST']
# ['DD']
# ['EQIX' 'ESS' 'PSA' 'SPG']
# ['FLT' 'IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'ANTM' 'BAX' 'BMY' 'BSX' 'CAH'
#  'CERN' 'CI' 'CNC' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA'
#  'HOLX' 'HSIC' 'HUM' 'IDXX' 'INCY' 'IQV' 'JNJ' 'LH' 'LLY' 'MDT' 'MRK'
#  'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'UHS' 'UNH' 'VRTX' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GD' 'GE' 'GNRC' 'HII'
#  'HON' 'HWM' 'IEX' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LUV' 'MAS'
#  'NLSN' 'NSC' 'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'SNA'
#  'SWK' 'TDY' 'TT' 'TXT' 'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'WHR'
#  'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANSS' 'APH'
#  'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS' 'FISV'
#  'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR' 'KLAC'
#  'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW' 'NTAP'
#  'NVDA' 'NXPI' 'ORCL' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX' 'SWKS' 'TEL' 'TER'
#  'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'MTB' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SPGI' 'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'APD' 'AVY' 'BLL' 'CE' 'CF' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP'
#  'LYB' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'AMGN' 'BDX' 'BIIB' 'BIO' 'COO' 'ILMN' 'ISRG' 'MCK' 'MTD' 'PRGO'
#  'REGN' 'TMO' 'WAT']
# ['AMT' 'ARE' 'AVB' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST'
#  'IRM' 'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL'
#  'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY' 'EXPE' 'F'
#  'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB' 'LEG' 'LEN'
#  'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM'
#  'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA' 'ULTA'
#  'VFC']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['BA' 'CMI' 'FDX' 'GWW' 'LMT' 'MMM' 'NOC' 'PH' 'ROK' 'ROP' 'TDG']
# []
# ['BLK' 'GS' 'RE' 'SIVB']
# ['CHTR' 'GOOG' 'GOOGL']
# ['DD' 'MLM']
# ['EQIX' 'ESS' 'PSA' 'SPG']
# ['FFIV' 'FLT' 'IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'AMGN' 'ANTM' 'BAX' 'BMY' 'BSX'
#  'CAH' 'CERN' 'CI' 'CNC' 'CRL' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD'
#  'HCA' 'HOLX' 'HSIC' 'IDXX' 'INCY' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE'
#  'PKI' 'RMD' 'STE' 'SYK' 'TFX' 'UHS' 'UNH' 'VRTX' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GD' 'GE' 'GNRC' 'HII'
#  'HON' 'HWM' 'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LUV'
#  'MAS' 'NLSN' 'NSC' 'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX'
#  'SWK' 'TDY' 'TT' 'TXT' 'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'WHR'
#  'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS'
#  'FISV' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX'
#  'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'COST' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K'
#  'KMB' 'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ'
#  'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN' 'HIG'
#  'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW' 'SPGI'
#  'STT' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'ECL' 'EMN' 'FCX' 'FMC' 'IFF' 'IP' 'LYB'
#  'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'BDX' 'BIIB' 'BIO' 'COO' 'HUM' 'ILMN' 'ISRG' 'LH' 'MCK' 'MTD'
#  'PRGO' 'REGN' 'TMO' 'WAT']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'SBAC' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'DD' 'MLM']
# ['APTV' 'BBY' 'BWA' 'CCL' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY' 'EXPE' 'F'
#  'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB' 'LEG' 'LEN'
#  'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM'
#  'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA' 'ULTA'
#  'VFC']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA' 'SPG']
# ['BA' 'CMI' 'FDX' 'GWW' 'LMT' 'MMM' 'NOC' 'PH' 'ROK' 'ROP' 'SNA' 'TDG']
# []
# ['BLK' 'GS' 'MTB' 'RE' 'SIVB']
# ['CHTR' 'GOOG' 'GOOGL']
# ['FFIV' 'FLT' 'IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CI'
#  'CNC' 'CRL' 'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA'
#  'HOLX' 'HSIC' 'IDXX' 'INCY' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI'
#  'RMD' 'STE' 'SYK' 'UNH' 'VRTX' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HII' 'HON'
#  'HWM' 'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN'
#  'NSC' 'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'SWK' 'TDY' 'TT'
#  'TXT' 'UAL' 'UNP' 'UPS' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'WHR'
#  'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS'
#  'FISV' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX'
#  'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'TYL' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KMB' 'KO'
#  'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ' 'SYY' 'TAP'
#  'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CFG' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN'
#  'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS'
#  'MSCI' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SPGI' 'STT' 'SYF' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'EMN' 'FCX' 'FMC' 'IP' 'LYB' 'MOS' 'NEM'
#  'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'COO' 'HUM' 'ILMN' 'ISRG' 'LH'
#  'MCK' 'MTD' 'PRGO' 'REGN' 'TFX' 'TMO' 'UHS' 'WAT']
# ['AMP' 'BLK' 'GS' 'MTB' 'RE' 'SIVB']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM'
#  'KIM' 'MAA' 'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'DD' 'ECL' 'IFF' 'MLM']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB'
#  'LEG' 'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN'
#  'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA'
#  'ULTA' 'VFC']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'PSA' 'SBAC' 'SPG']
# ['BA' 'CMI' 'FDX' 'GD' 'GWW' 'KSU' 'LMT' 'MMM' 'NOC' 'PH' 'ROK' 'ROP'
#  'SNA' 'TDG' 'URI']
# []
# ['CHTR' 'GOOG' 'GOOGL']
# ['COST']
# ['FFIV' 'FLT' 'IBM']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CI'
#  'CNC' 'CRL' 'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA'
#  'HOLX' 'HSIC' 'IDXX' 'INCY' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI'
#  'RMD' 'STE' 'SYK' 'UNH' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HII' 'HON'
#  'HWM' 'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN'
#  'NSC' 'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROK' 'ROL' 'RSG' 'RTX' 'SWK' 'TT'
#  'TXT' 'UAL' 'UNP' 'UPS' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'ULTA'
#  'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS'
#  'FISV' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KEYS' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK'
#  'NOW' 'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'QCOM' 'SNPS' 'STX'
#  'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KMB' 'KO'
#  'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'STZ' 'SYY' 'TAP'
#  'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CFG' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN'
#  'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS'
#  'MSCI' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SPGI' 'STT' 'SYF' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'EMN' 'FCX' 'FMC' 'IFF' 'IP' 'LYB' 'MOS'
#  'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'COO' 'HUM' 'ILMN' 'ISRG' 'LH'
#  'MCK' 'MTD' 'PRGO' 'REGN' 'TFX' 'TMO' 'UHS' 'VRTX' 'WAT']
# ['AMP' 'BLK' 'GS' 'MTB' 'RE' 'SIVB']
# ['AMT' 'ARE' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'HST' 'IRM' 'KIM' 'MAA'
#  'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'DD' 'ECL' 'MLM']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB'
#  'LEG' 'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN'
#  'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA'
#  'VFC']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'BXP' 'EQIX' 'ESS' 'FRT' 'PSA' 'SBAC' 'SPG']
# ['BA' 'CMI' 'FDX' 'GD' 'GWW' 'KSU' 'LMT' 'MMM' 'NOC' 'PH' 'ROP' 'SNA'
#  'TDG' 'TDY' 'URI']
# []
# ['CHTR' 'GOOG' 'GOOGL']
# ['COST']
# ['FFIV' 'FLT' 'IBM' 'TYL']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC'
#  'CRL' 'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA' 'HOLX'
#  'HSIC' 'IDXX' 'INCY' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD'
#  'STE' 'SYK' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HON' 'HWM'
#  'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN' 'NSC'
#  'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROK' 'ROL' 'RSG' 'RTX' 'SWK' 'TT' 'TXT'
#  'UAL' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL' 'ULTA'
#  'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'AVGO' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS'
#  'FISV' 'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KEYS' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK'
#  'NOW' 'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'QCOM' 'QRVO'
#  'SNPS' 'STX' 'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KMB' 'KO'
#  'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'SYY' 'TAP' 'TSN'
#  'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CFG' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN'
#  'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS'
#  'MSCI' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SPGI' 'STT' 'SYF' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'EMN' 'FCX' 'FMC' 'IP' 'LYB' 'MOS' 'NEM'
#  'NUE' 'PKG' 'SEE' 'SHW' 'VMC']
# ['ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'HUM' 'ILMN' 'ISRG'
#  'LH' 'MCK' 'MTD' 'PRGO' 'REGN' 'TFX' 'TMO' 'UHS' 'UNH' 'VRTX' 'WAT']
# ['AMP' 'BLK' 'GS' 'MTB' 'RE' 'SIVB']
# ['AMT' 'ARE' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'HST' 'IRM' 'KIM' 'MAA'
#  'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'DD' 'ECL' 'IFF' 'MLM' 'PPG']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DG' 'DHI' 'DLTR' 'DPZ' 'DRI' 'EBAY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB'
#  'LEG' 'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN'
#  'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA'
#  'VFC']
# ['ATVI' 'CMCSA' 'DIS' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV'
#  'NFLX' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'BXP' 'EQIX' 'ESS' 'FRT' 'PSA' 'SBAC' 'SPG']
# ['BA' 'CMI' 'FDX' 'GD' 'GWW' 'HII' 'KSU' 'LMT' 'MMM' 'NOC' 'PH' 'ROP'
#  'SNA' 'TDG' 'TDY' 'UNP']
# []
# ['CHTR' 'GOOG' 'GOOGL']
# ['COST' 'STZ']
# ['FFIV' 'FLT' 'IBM' 'TYL']
# ['PXD']
# ['A' 'ABBV' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC' 'CRL'
#  'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA' 'HOLX' 'HSIC'
#  'IDXX' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK' 'WST'
#  'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HON' 'HWM'
#  'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN'
#  'NSC' 'ODFL' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'SWK' 'TT' 'TXT'
#  'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DPZ' 'MHK' 'NVR' 'ORLY' 'PVH' 'RL'
#  'ULTA' 'WHR' 'WYNN']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS' 'FISV'
#  'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR' 'KEYS'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'QCOM' 'QRVO' 'SNPS'
#  'STX' 'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ABC' 'ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'HUM' 'ILMN'
#  'INCY' 'ISRG' 'LH' 'MCK' 'MTD' 'PRGO' 'REGN' 'TFX' 'TMO' 'UHS' 'UNH'
#  'VRTX' 'WAT']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KMB' 'KO'
#  'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'SYY' 'TAP' 'TSN'
#  'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CFG' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN'
#  'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MET' 'MKTX' 'MMC' 'MS' 'MSCI'
#  'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW' 'SPGI'
#  'STT' 'SYF' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'EMN' 'FCX' 'FMC' 'IP' 'LYB' 'MOS' 'NEM'
#  'NUE' 'PKG' 'SEE' 'SHW' 'VMC' 'WRK']
# ['AMP' 'BLK' 'GS' 'MCO' 'MTB' 'RE' 'SIVB']
# ['AMT' 'ARE' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'HST' 'IRM' 'KIM' 'MAA'
#  'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'DD' 'ECL' 'IFF' 'MLM' 'PPG']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DG' 'DHI' 'DLTR' 'DRI' 'EBAY' 'ETSY'
#  'EXPE' 'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HD' 'HLT' 'KMX' 'LB'
#  'LEG' 'LEN' 'LKQ' 'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN'
#  'PHM' 'POOL' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA'
#  'VFC']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV' 'NFLX'
#  'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'BXP' 'EQIX' 'ESS' 'FRT' 'PSA' 'SBAC' 'SPG']
# ['AVGO' 'FFIV' 'FLT' 'IBM' 'TYL']
# ['BA' 'CMI' 'FDX' 'GD' 'GWW' 'HII' 'LMT' 'MMM' 'NOC' 'PH' 'ROK' 'ROP'
#  'SNA' 'TDG' 'TDY']
# []
# ['CHTR' 'DIS' 'GOOG' 'GOOGL']
# ['COST' 'STZ']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC'
#  'CRL' 'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA' 'HOLX'
#  'HSIC' 'IDXX' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK'
#  'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CPRT' 'CSX' 'CTAS' 'DAL'
#  'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HON' 'HWM'
#  'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN'
#  'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI' 'ROK' 'ROL' 'RSG' 'RTX' 'SWK'
#  'TT' 'TXT' 'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DPZ' 'EXPE' 'HD' 'MHK' 'NVR' 'ORLY'
#  'PVH' 'RL' 'ULTA' 'WHR']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS' 'FISV'
#  'FTNT' 'GLW' 'GPN' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR' 'KEYS'
#  'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK' 'NOW'
#  'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'PYPL' 'QCOM' 'QRVO'
#  'SNPS' 'STX' 'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'V' 'VRSN' 'WDC' 'WU' 'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CLX' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KHC' 'KMB'
#  'KO' 'KR' 'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SJM' 'SYY' 'TAP'
#  'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CFG' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN'
#  'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS'
#  'MSCI' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SPGI' 'STT' 'SYF' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'DD' 'EMN' 'FCX' 'FMC' 'IP' 'LYB' 'MOS' 'NEM'
#  'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC' 'WRK']
# ['ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'HUM' 'ILMN' 'INCY'
#  'ISRG' 'LH' 'MCK' 'MTD' 'PRGO' 'REGN' 'TFX' 'TMO' 'UHS' 'UNH' 'VRTX'
#  'WAT']
# ['AMP' 'BLK' 'GS' 'MTB' 'RE' 'SIVB']
# ['AMT' 'ARE' 'BXP' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'HST' 'IRM' 'KIM'
#  'MAA' 'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'ECL' 'IFF' 'MLM']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DG' 'DHI' 'DLTR' 'DRI' 'EBAY' 'ETSY' 'F'
#  'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HLT' 'KMX' 'LB' 'LEG' 'LEN' 'LKQ'
#  'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM' 'POOL'
#  'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA' 'VFC' 'WYNN']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'EA' 'FB' 'IPG' 'LUMN' 'LYV' 'NWS'
#  'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'EQIX' 'ESS' 'FRT' 'PSA' 'SBAC' 'SPG']
# ['AVGO' 'FFIV' 'FLT' 'IBM' 'TYL']
# ['BA' 'CMI' 'FDX' 'GD' 'GWW' 'HII' 'LMT' 'MMM' 'NOC' 'ROP' 'SNA' 'TDG'
#  'TDY']
# []
# ['CHTR' 'DIS' 'GOOG' 'GOOGL' 'NFLX']
# ['COST' 'STZ']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC'
#  'CRL' 'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA' 'HOLX'
#  'HSIC' 'IDXX' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD' 'STE' 'SYK'
#  'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS'
#  'DAL' 'DE' 'DOV' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HON' 'HWM'
#  'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LUV' 'MAS' 'NLSN'
#  'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI' 'ROK' 'ROL' 'RSG' 'RTX' 'SWK'
#  'TDY' 'TT' 'TXT' 'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DPZ' 'EXPE' 'HD' 'MHK' 'NVR' 'ORLY' 'RL'
#  'ULTA' 'WHR']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FIS' 'FISV'
#  'FTNT' 'GLW' 'GPN' 'HPE' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY' 'JNPR'
#  'KEYS' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM' 'NLOK'
#  'NOW' 'NTAP' 'NVDA' 'NXPI' 'ORCL' 'PAYC' 'PAYX' 'PTC' 'PYPL' 'QCOM'
#  'QRVO' 'SNPS' 'STX' 'SWKS' 'TEL' 'TER' 'TRMB' 'TXN' 'V' 'VRSN' 'WDC' 'WU'
#  'XLNX']
# ['ADM' 'CAG' 'CHD' 'CL' 'CPB' 'EL' 'GIS' 'HRL' 'HSY' 'K' 'KHC' 'KO' 'KR'
#  'MDLZ' 'MKC' 'MNST' 'MO' 'PEP' 'PG' 'PM' 'SYY' 'TAP' 'TSN' 'WBA' 'WMT']
# ['AEE' 'AEP' 'AES' 'ATO' 'AWK' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES'
#  'ETR' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'SRE'
#  'WEC' 'XEL']
# ['AFL' 'AIG' 'AIZ' 'AJG' 'ALL' 'AMP' 'AON' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CB'
#  'CBOE' 'CFG' 'CINF' 'CMA' 'CME' 'COF' 'DFS' 'FITB' 'FRC' 'GL' 'HBAN'
#  'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC' 'MCO' 'MET' 'MKTX' 'MMC' 'MS'
#  'MSCI' 'NDAQ' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PNC' 'PRU' 'RF' 'RJF' 'SCHW'
#  'SPGI' 'STT' 'SYF' 'TFC' 'TROW' 'TRV' 'UNM' 'USB' 'WFC' 'WRB']
# ['ALB' 'AVY' 'BLL' 'CE' 'CF' 'EMN' 'FCX' 'FMC' 'IP' 'LYB' 'MOS' 'NEM'
#  'NUE' 'PKG' 'PPG' 'SEE' 'SHW' 'VMC' 'WRK']
# ['ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'HUM' 'ILMN' 'INCY'
#  'ISRG' 'LH' 'MCK' 'MTD' 'PRGO' 'REGN' 'TFX' 'TMO' 'UHS' 'UNH' 'VRTX'
#  'WAT']
# ['AMT' 'ARE' 'CBRE' 'CCI' 'DLR' 'DRE' 'EQR' 'EXR' 'HST' 'IRM' 'KIM' 'MAA'
#  'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['APA' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'DD' 'ECL' 'IFF' 'MLM']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DG' 'DHI' 'DLTR' 'DRI' 'EBAY' 'ETSY' 'F'
#  'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HLT' 'KMX' 'LB' 'LEG' 'LEN' 'LKQ'
#  'LOW' 'LVS' 'MAR' 'MCD' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM' 'POOL'
#  'PVH' 'RCL' 'ROST' 'SBUX' 'TGT' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UAA' 'VFC'
#  'WYNN']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'EA' 'IPG' 'LUMN' 'LYV' 'NWS'
#  'NWSA' 'OMC' 'T' 'TMUS' 'TTWO' 'TWTR' 'VIAC' 'VZ']
# ['AVB' 'BXP' 'EQIX' 'ESS' 'FRT' 'PSA' 'SBAC' 'SPG']
# ['AVGO' 'FFIV' 'FLT' 'IBM' 'TYL']
# ['BA' 'EFX' 'FDX' 'GD' 'GWW' 'HII' 'LMT' 'MMM' 'NOC' 'ROP' 'SNA' 'TDG']
# []
# ['BLK' 'GS' 'MTB' 'RE' 'SIVB']
# ['CHTR' 'DIS' 'FB' 'GOOG' 'GOOGL' 'NFLX']
# ['CLX' 'COST' 'KMB' 'SJM' 'STZ']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABMD' 'ABT' 'ALGN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC'
#  'CRL' 'CTLT' 'CVS' 'DGX' 'DHR' 'DVA' 'DXCM' 'EW' 'GILD' 'HCA' 'HOLX'
#  'HSIC' 'IDXX' 'INCY' 'IQV' 'JNJ' 'LLY' 'MDT' 'MRK' 'PFE' 'PKI' 'RMD'
#  'STE' 'SYK' 'VRTX' 'WST' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CAT' 'CHRW' 'CMI' 'CPRT' 'CSX' 'CTAS'
#  'DAL' 'DE' 'DOV' 'EFX' 'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'GE' 'GNRC' 'HON'
#  'HWM' 'IEX' 'INFO' 'ITW' 'J' 'JBHT' 'JCI' 'KSU' 'LDOS' 'LHX' 'LUV' 'MAS'
#  'NLSN' 'NSC' 'ODFL' 'PCAR' 'PH' 'PNR' 'PWR' 'RHI' 'ROK' 'ROL' 'RSG' 'RTX'
#  'SWK' 'TDY' 'TT' 'TXT' 'UAL' 'UNP' 'UPS' 'URI' 'VRSK' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DPZ' 'EXPE' 'HD' 'MCD' 'MHK' 'NVR'
#  'ORLY' 'ULTA' 'WHR']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'AMAT' 'AMD' 'ANET' 'ANSS'
#  'APH' 'BR' 'CDNS' 'CDW' 'CRM' 'CSCO' 'CTSH' 'CTXS' 'ENPH' 'FFIV' 'FIS'
#  'FISV' 'FTNT' 'GLW' 'GPN' 'HPE' 'HPQ' 'INTC' 'INTU' 'IPGP' 'IT' 'JKHY'
#  'JNPR' 'KEYS' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'MU' 'MXIM'
# ...
#  'ITW' 'JBHT' 'KSU' 'LHX' 'LMT' 'MMM' 'NOC' 'NSC' 'ODFL' 'PH' 'ROK' 'ROP'
#  'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'UNP' 'UPS' 'URI' 'VRSK' 'WM']
# []
# ['CBRE' 'DRE' 'EQR' 'HST' 'IRM' 'KIM' 'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO'
#  'VTR' 'WELL' 'WY']
# ['CHTR' 'DIS' 'FB' 'GOOG' 'GOOGL' 'NFLX' 'TTWO']
# ['CLX' 'COST' 'EL' 'HSY' 'KMB' 'PEP' 'PG' 'SJM' 'STZ' 'WMT']
# ['CVX' 'PXD']
# ['A' 'ABBV' 'ABC' 'ABT' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC' 'CTLT' 'CVS'
#  'DVA' 'EW' 'GILD' 'HOLX' 'HSIC' 'INCY' 'MRK' 'PFE' 'PKI' 'PRGO' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'CHRW' 'CPRT' 'CSX' 'DAL' 'EMR' 'ETN' 'EXPD'
#  'FAST' 'FBHS' 'FTV' 'GE' 'GNRC' 'HWM' 'INFO' 'IR' 'J' 'JCI' 'LDOS' 'LUV'
#  'MAS' 'NLSN' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'TXT' 'UAL' 'WAB'
#  'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DG' 'DLTR' 'DPZ' 'DRI' 'EXPE' 'HD' 'HLT'
#  'LOW' 'MAR' 'MCD' 'MHK' 'NVR' 'ORLY' 'POOL' 'RCL' 'RL' 'ROST' 'TGT'
#  'ULTA' 'WHR' 'WYNN']
# ['AAPL' 'AKAM' 'AMAT' 'AMD' 'APH' 'CDNS' 'CSCO' 'CTSH' 'DXC' 'ENPH' 'FTNT'
#  'GLW' 'HPE' 'HPQ' 'INTC' 'JNPR' 'MCHP' 'MU' 'MXIM' 'NLOK' 'NTAP' 'ORCL'
#  'PAYX' 'PTC' 'QCOM' 'QRVO' 'STX' 'SWKS' 'TEL' 'TER' 'TRMB' 'WDC' 'WU'
#  'XLNX']
# ['ABMD' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'CRL'
#  'DGX' 'DHR' 'DXCM' 'HCA' 'HUM' 'IDXX' 'ILMN' 'IQV' 'ISRG' 'JNJ' 'LH'
#  'LLY' 'MCK' 'MDT' 'MTD' 'REGN' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS' 'UNH'
#  'VRTX' 'WAT' 'WST']
# ['ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'ANET' 'ANSS' 'AVGO' 'BR' 'CDW' 'CRM'
#  'CTXS' 'FFIV' 'FIS' 'FISV' 'FLT' 'GPN' 'IBM' 'INTU' 'IPGP' 'IT' 'JKHY'
#  'KEYS' 'KLAC' 'LRCX' 'MA' 'MPWR' 'MSFT' 'MSI' 'NOW' 'NVDA' 'NXPI' 'PAYC'
#  'PYPL' 'SNPS' 'TXN' 'TYL' 'V' 'VRSN']
# ['ADM' 'CAG' 'CHD' 'CL' 'CPB' 'GIS' 'HRL' 'K' 'KHC' 'KO' 'KR' 'LW' 'MDLZ'
#  'MKC' 'MNST' 'MO' 'PM' 'SYY' 'TAP' 'TSN' 'WBA']
# ['AEE' 'AEP' 'AES' 'CMS' 'CNP' 'D' 'DUK' 'ED' 'EIX' 'ES' 'EVRG' 'EXC' 'FE'
#  'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'WEC' 'XEL']
# ['AFL' 'AIG' 'AJG' 'BAC' 'BEN' 'BK' 'C' 'CFG' 'CMA' 'COF' 'DFS' 'FITB'
#  'GL' 'HBAN' 'HIG' 'ICE' 'IVZ' 'KEY' 'L' 'LNC' 'MET' 'MS' 'NDAQ' 'NTRS'
#  'PBCT' 'PFG' 'PGR' 'PRU' 'RF' 'RJF' 'SCHW' 'STT' 'SYF' 'TFC' 'UNM' 'USB'
#  'WFC' 'WRB']
# ['AIZ' 'ALL' 'AMP' 'AON' 'AXP' 'BLK' 'CB' 'CBOE' 'CINF' 'CME' 'FRC' 'GS'
#  'JPM' 'MCO' 'MKTX' 'MMC' 'MSCI' 'MTB' 'PNC' 'RE' 'SIVB' 'SPGI' 'TROW'
#  'TRV' 'WLTW']
# ['ALB' 'AMCR' 'BLL' 'CF' 'CTVA' 'DD' 'DOW' 'EMN' 'FCX' 'FMC' 'IP' 'LYB'
#  'MOS' 'NEM' 'NUE' 'SEE' 'WRK']
# ['ALLE' 'BA' 'CAT' 'CMI' 'CTAS' 'DE' 'DOV' 'EFX' 'FDX' 'GD' 'GWW' 'HII'
#  'HON' 'IEX' 'ITW' 'JBHT' 'KSU' 'LHX' 'LMT' 'MMM' 'NOC' 'NSC' 'ODFL' 'PH'
#  'ROK' 'ROP' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'UNP' 'UPS' 'URI' 'VRSK' 'WM']
# ['AMT' 'ARE' 'AVB' 'BXP' 'CCI' 'DLR' 'EQIX' 'ESS' 'EXR' 'FRT' 'MAA' 'PSA'
#  'SBAC' 'SPG']
# ['APA' 'BKR' 'COG' 'COP' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC' 'MRO'
#  'NOV' 'OKE' 'OXY' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'AVY' 'CE' 'ECL' 'IFF' 'LIN' 'MLM' 'PKG' 'PPG' 'SHW' 'VMC']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DHI' 'EBAY' 'ETSY' 'F' 'GM' 'GPC' 'GPS'
#  'GRMN' 'HAS' 'HBI' 'KMX' 'LB' 'LEG' 'LEN' 'LKQ' 'LVS' 'MGM' 'NCLH' 'NKE'
#  'NWL' 'PENN' 'PHM' 'PVH' 'SBUX' 'TJX' 'TPR' 'TSCO' 'TSLA' 'UA' 'UAA'
#  'VFC']
# ['ATO' 'AWK' 'DTE' 'ETR' 'SRE']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'EA' 'FOX' 'FOXA' 'IPG' 'LUMN'
#  'LYV' 'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TWTR' 'VIAC' 'VZ']
# []
# ['CBRE' 'DRE' 'EQR' 'HST' 'IRM' 'KIM' 'O' 'PEAK' 'PLD' 'REG' 'UDR' 'VNO'
#  'VTR' 'WELL' 'WY']
# ['CHTR' 'DIS' 'FB' 'GOOG' 'GOOGL' 'NFLX' 'TTWO']
# ['CLX' 'COST' 'EL' 'HSY' 'KMB' 'PEP' 'PG' 'SJM' 'STZ' 'WMT']
# ['CVX' 'PSX' 'PXD']
# ['A' 'ABBV' 'ABC' 'ABT' 'ALXN' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC' 'CTLT'
#  'CVS' 'DVA' 'EW' 'GILD' 'HOLX' 'HSIC' 'INCY' 'MRK' 'PFE' 'PKI' 'PRGO'
#  'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'CARR' 'CHRW' 'CPRT' 'CSX' 'DAL' 'EMR' 'ETN'
#  'EXPD' 'FAST' 'FBHS' 'FTV' 'GE' 'HWM' 'INFO' 'IR' 'J' 'JCI' 'LDOS' 'LUV'
#  'MAS' 'NLSN' 'OTIS' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'TXT'
#  'UAL' 'UPS' 'WAB' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DG' 'DPZ' 'HD' 'LOW' 'MAR' 'MCD' 'MHK'
#  'NVR' 'ORLY' 'POOL' 'RL' 'ROST' 'TGT' 'TSLA' 'ULTA' 'WHR' 'WYNN']
# ['AAPL' 'AKAM' 'AMAT' 'AMD' 'APH' 'CDNS' 'CSCO' 'CTSH' 'DXC' 'ENPH' 'GLW'
#  'HPE' 'HPQ' 'INTC' 'JNPR' 'KEYS' 'MCHP' 'MU' 'MXIM' 'NLOK' 'NTAP' 'ORCL'
#  'PAYX' 'PTC' 'QCOM' 'STX' 'TEL' 'TER' 'TRMB' 'WDC' 'WU' 'XLNX']
# ['ABMD' 'ALGN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'CRL' 'DGX'
#  'DHR' 'DXCM' 'HCA' 'HUM' 'IDXX' 'ILMN' 'IQV' 'ISRG' 'JNJ' 'LH' 'LLY'
#  'MCK' 'MDT' 'MTD' 'REGN' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS' 'UNH' 'VRTX'
#  'WAT' 'WST']
# ['ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'ANET' 'ANSS' 'AVGO' 'BR' 'CDW' 'CRM'
#  'CTXS' 'FFIV' 'FIS' 'FISV' 'FLT' 'FTNT' 'GPN' 'IBM' 'INTU' 'IPGP' 'IT'
#  'JKHY' 'KLAC' 'LRCX' 'MA' 'MPWR' 'MSFT' 'MSI' 'NOW' 'NVDA' 'NXPI' 'PAYC'
#  'PYPL' 'QRVO' 'SNPS' 'SWKS' 'TXN' 'TYL' 'V' 'VRSN']
# ['ADM' 'CAG' 'CHD' 'CL' 'CPB' 'GIS' 'HRL' 'K' 'KHC' 'KO' 'KR' 'LW' 'MDLZ'
#  'MKC' 'MNST' 'MO' 'PM' 'SYY' 'TAP' 'TSN' 'WBA']
# ['AEE' 'AEP' 'AES' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES' 'EVRG'
#  'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'WEC' 'XEL']
# ['AFL' 'AIG' 'AJG' 'BAC' 'BEN' 'BK' 'C' 'CFG' 'CINF' 'CMA' 'COF' 'DFS'
#  'FITB' 'GL' 'HBAN' 'HIG' 'ICE' 'IVZ' 'KEY' 'L' 'LNC' 'MET' 'MS' 'NTRS'
#  'PBCT' 'PFG' 'PGR' 'PRU' 'RF' 'RJF' 'SCHW' 'STT' 'SYF' 'TFC' 'UNM' 'USB'
#  'WFC' 'WRB']
# ['AIZ' 'ALL' 'AMP' 'AON' 'AXP' 'BLK' 'CB' 'CBOE' 'CME' 'FRC' 'GS' 'JPM'
#  'MCO' 'MKTX' 'MMC' 'MSCI' 'MTB' 'NDAQ' 'PNC' 'RE' 'SIVB' 'SPGI' 'TROW'
#  'TRV' 'WLTW']
# ['ALB' 'AMCR' 'BLL' 'CE' 'CF' 'CTVA' 'DD' 'DOW' 'EMN' 'FCX' 'FMC' 'IP'
#  'LYB' 'MOS' 'NEM' 'NUE' 'PKG' 'SEE' 'WRK']
# ['ALLE' 'BA' 'CAT' 'CMI' 'CTAS' 'DE' 'DOV' 'EFX' 'FDX' 'GD' 'GNRC' 'GWW'
#  'HII' 'HON' 'IEX' 'ITW' 'JBHT' 'KSU' 'LHX' 'LMT' 'MMM' 'NOC' 'NSC' 'ODFL'
#  'PH' 'ROK' 'ROP' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'UNP' 'URI' 'VRSK' 'WM']
# ['AMT' 'ARE' 'AVB' 'BXP' 'CCI' 'DLR' 'EQIX' 'ESS' 'FRT' 'MAA' 'PSA' 'SBAC'
#  'SPG']
# ['APA' 'BKR' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC'
#  'MRO' 'NOV' 'OKE' 'OXY' 'PSX' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'AVY' 'ECL' 'IFF' 'LIN' 'MLM' 'PPG' 'SHW' 'VMC']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DHI' 'DLTR' 'DRI' 'EBAY' 'ETSY' 'EXPE'
#  'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HLT' 'KMX' 'LB' 'LEG' 'LEN'
#  'LKQ' 'LVS' 'MGM' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM' 'PVH' 'RCL' 'SBUX'
#  'TJX' 'TPR' 'TSCO' 'UA' 'UAA' 'VFC']
# ['ATO' 'AWK' 'ETR' 'SRE']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'FOX' 'FOXA' 'IPG' 'LUMN' 'LYV'
#  'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TWTR' 'VIAC' 'VZ']
# []
# ['CBRE' 'DRE' 'EQR' 'EXR' 'HST' 'IRM' 'KIM' 'O' 'PEAK' 'PLD' 'REG' 'UDR'
#  'VNO' 'VTR' 'WELL' 'WY']
# ['CHTR' 'DIS' 'EA' 'FB' 'GOOG' 'GOOGL' 'NFLX' 'TTWO']
# ['CLX' 'COST' 'EL' 'HSY' 'KMB' 'PEP' 'PG' 'SJM' 'STZ' 'WMT']
# ['PXD']
# ['A' 'ABBV' 'ABC' 'ABT' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC' 'CTLT' 'CVS'
#  'DVA' 'EW' 'GILD' 'HOLX' 'HSIC' 'INCY' 'MDT' 'MRK' 'PFE' 'PKI' 'PRGO'
#  'UHS' 'XRAY']
# ['AAL' 'ALK' 'ALLE' 'AME' 'AOS' 'CARR' 'CHRW' 'CPRT' 'CSX' 'DAL' 'DOV'
#  'EMR' 'ETN' 'EXPD' 'FAST' 'FBHS' 'FTV' 'GE' 'HWM' 'INFO' 'IR' 'J' 'JCI'
#  'LDOS' 'LUV' 'MAS' 'NLSN' 'OTIS' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG'
#  'RTX' 'TT' 'TXT' 'UAL' 'UPS' 'WAB' 'WM' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BKNG' 'CMG' 'DG' 'DPZ' 'HD' 'LOW' 'MCD' 'NVR' 'ORLY'
#  'POOL' 'TGT' 'TSCO' 'TSLA' 'ULTA' 'WHR']
# ['AAPL' 'AMAT' 'AMD' 'APH' 'CDNS' 'CSCO' 'CTSH' 'DXC' 'ENPH' 'GLW' 'HPE'
#  'HPQ' 'INTC' 'JNPR' 'KEYS' 'MCHP' 'MU' 'MXIM' 'NLOK' 'NTAP' 'NXPI' 'ORCL'
#  'PAYX' 'PTC' 'QCOM' 'QRVO' 'STX' 'TEL' 'TER' 'TRMB' 'WDC' 'WU' 'XLNX']
# ['ABMD' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO' 'CRL'
#  'DGX' 'DHR' 'DXCM' 'HCA' 'HUM' 'IDXX' 'ILMN' 'IQV' 'ISRG' 'JNJ' 'LH'
#  'LLY' 'MCK' 'MTD' 'REGN' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UNH' 'VRTX' 'WAT'
#  'WST']
# ['ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'ANET' 'ANSS' 'AVGO' 'BR' 'CDW'
#  'CRM' 'CTXS' 'FFIV' 'FIS' 'FISV' 'FLT' 'FTNT' 'GPN' 'IBM' 'INTU' 'IPGP'
#  'IT' 'JKHY' 'KLAC' 'LRCX' 'MA' 'MPWR' 'MSFT' 'MSI' 'NOW' 'NVDA' 'PAYC'
#  'PYPL' 'SNPS' 'SWKS' 'TXN' 'TYL' 'V' 'VRSN']
# ['ADM' 'CAG' 'CHD' 'CL' 'CPB' 'GIS' 'HRL' 'K' 'KHC' 'KO' 'KR' 'LW' 'MDLZ'
#  'MKC' 'MNST' 'MO' 'PM' 'SYY' 'TAP' 'TSN' 'WBA']
# ['AEE' 'AEP' 'AES' 'ATO' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES' 'ETR'
#  'EVRG' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'WEC'
#  'XEL']
# ['AFL' 'AIG' 'AJG' 'ALL' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CBOE' 'CFG' 'CINF'
#  'CMA' 'COF' 'DFS' 'FITB' 'GL' 'HBAN' 'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L'
#  'LNC' 'MET' 'MMC' 'MS' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PRU' 'RF' 'RJF' 'SCHW'
#  'STT' 'SYF' 'TFC' 'UNM' 'USB' 'WFC' 'WRB']
# ['AIZ' 'AMP' 'AON' 'BLK' 'CB' 'CME' 'FRC' 'GS' 'MCO' 'MKTX' 'MSCI' 'MTB'
#  'NDAQ' 'PNC' 'RE' 'SIVB' 'SPGI' 'TROW' 'TRV' 'WLTW']
# ['ALB' 'AMCR' 'BLL' 'CE' 'CF' 'CTVA' 'DD' 'DOW' 'EMN' 'FCX' 'FMC' 'IP'
#  'LYB' 'MOS' 'NEM' 'NUE' 'PKG' 'PPG' 'SEE' 'WRK']
# ['AMT' 'ARE' 'AVB' 'CCI' 'DLR' 'EQIX' 'ESS' 'MAA' 'PSA' 'SBAC']
# ['APA' 'BKR' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC'
#  'MRO' 'NOV' 'OKE' 'OXY' 'PSX' 'PXD' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'AVY' 'ECL' 'IFF' 'LIN' 'MLM' 'SHW' 'VMC']
# ['APTV' 'BBY' 'BWA' 'CCL' 'CZR' 'DHI' 'DLTR' 'DRI' 'EBAY' 'ETSY' 'EXPE'
#  'F' 'GM' 'GPC' 'GPS' 'GRMN' 'HAS' 'HBI' 'HLT' 'KMX' 'LB' 'LEG' 'LEN'
#  'LKQ' 'LVS' 'MAR' 'MGM' 'MHK' 'NCLH' 'NKE' 'NWL' 'PENN' 'PHM' 'PVH' 'RCL'
#  'RL' 'ROST' 'SBUX' 'TJX' 'TPR' 'UA' 'UAA' 'VFC' 'WYNN']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'FOX' 'FOXA' 'IPG' 'LUMN' 'LYV'
#  'NWS' 'NWSA' 'OMC' 'T' 'TMUS' 'TWTR' 'VIAC' 'VZ']
# ['AWK' 'SRE']
# ['BA' 'CAT' 'CMI' 'CTAS' 'DE' 'EFX' 'FDX' 'GD' 'GNRC' 'GWW' 'HII' 'HON'
#  'IEX' 'ITW' 'JBHT' 'KSU' 'LHX' 'LMT' 'MMM' 'NOC' 'NSC' 'ODFL' 'PH' 'ROK'
#  'ROP' 'SNA' 'SWK' 'TDG' 'TDY' 'UNP' 'URI' 'VRSK']
# []
# ['BXP' 'CBRE' 'DRE' 'EQR' 'EXR' 'FRT' 'HST' 'IRM' 'KIM' 'O' 'PEAK' 'PLD'
#  'REG' 'SPG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['CHTR' 'DIS' 'EA' 'FB' 'GOOG' 'GOOGL' 'NFLX' 'TTWO']
# ['CLX' 'COST' 'EL' 'HSY' 'KMB' 'PEP' 'PG' 'SJM' 'STZ' 'WMT']
# ['A' 'ABBV' 'ABC' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC' 'CTLT' 'CVS' 'DVA'
#  'EW' 'GILD' 'HOLX' 'HSIC' 'INCY' 'MDT' 'MRK' 'PFE' 'PRGO' 'XRAY']
# ['AAL' 'ALK' 'AME' 'AOS' 'CARR' 'CHRW' 'CPRT' 'CSX' 'DAL' 'EMR' 'ETN'
#  'EXPD' 'FAST' 'FBHS' 'FTV' 'GE' 'HWM' 'INFO' 'IR' 'J' 'JCI' 'LDOS' 'LUV'
#  'MAS' 'NLSN' 'OTIS' 'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'TXT'
#  'UAL' 'WAB' 'XYL']
# ['AAP' 'AMZN' 'AZO' 'BBY' 'BKNG' 'CMG' 'DG' 'DPZ' 'ETSY' 'HD' 'LOW' 'MCD'
#  'NKE' 'NVR' 'ORLY' 'POOL' 'TGT' 'TSCO' 'TSLA' 'ULTA' 'WHR']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'ANET' 'ANSS' 'AVGO' 'BR'
#  'CDNS' 'CDW' 'CRM' 'CTXS' 'FFIV' 'FIS' 'FLT' 'FTNT' 'GPN' 'IBM' 'INTU'
#  'IPGP' 'IT' 'JKHY' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR' 'MSFT' 'MSI' 'NOW'
#  'NVDA' 'NXPI' 'PAYC' 'PYPL' 'QCOM' 'QRVO' 'SNPS' 'SWKS' 'TXN' 'TYL' 'V'
#  'VRSN' 'XLNX']
# ['ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI' 'COO'
#  'CRL' 'DGX' 'DHR' 'DXCM' 'HCA' 'HUM' 'IDXX' 'ILMN' 'IQV' 'ISRG' 'JNJ'
#  'LH' 'LLY' 'MCK' 'MTD' 'PKI' 'REGN' 'RMD' 'STE' 'SYK' 'TFX' 'TMO' 'UHS'
#  'UNH' 'VRTX' 'WAT' 'WST']
# ['ADM' 'CAG' 'CHD' 'CL' 'CPB' 'GIS' 'HRL' 'K' 'KHC' 'KO' 'KR' 'LW' 'MDLZ'
#  'MKC' 'MNST' 'MO' 'PM' 'SYY' 'TAP' 'TSN' 'WBA']
# ['AEE' 'AEP' 'AES' 'ATO' 'CMS' 'CNP' 'D' 'DTE' 'DUK' 'ED' 'EIX' 'ES' 'ETR'
#  'EVRG' 'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'WEC'
#  'XEL']
# ['AFL' 'AIG' 'ALL' 'AXP' 'BAC' 'BEN' 'BK' 'C' 'CBOE' 'CFG' 'CINF' 'CMA'
#  'COF' 'DFS' 'FITB' 'GL' 'HBAN' 'HIG' 'ICE' 'IVZ' 'JPM' 'KEY' 'L' 'LNC'
#  'MET' 'MS' 'MTB' 'NTRS' 'PBCT' 'PFG' 'PGR' 'PRU' 'RF' 'RJF' 'SCHW' 'STT'
#  'SYF' 'TFC' 'UNM' 'USB' 'WFC' 'WRB']
# ['AIZ' 'AJG' 'AMP' 'AON' 'BLK' 'CB' 'CME' 'FRC' 'GS' 'MCO' 'MKTX' 'MMC'
#  'MSCI' 'NDAQ' 'PNC' 'RE' 'SIVB' 'SPGI' 'TROW' 'TRV' 'WLTW']
# ['ALB' 'AMCR' 'BLL' 'CE' 'CF' 'CTVA' 'DD' 'DOW' 'EMN' 'FCX' 'IP' 'LYB'
#  'MOS' 'NEM' 'NUE' 'PKG' 'SEE' 'WRK']
# ['ALLE' 'BA' 'CAT' 'CMI' 'CTAS' 'DE' 'DOV' 'EFX' 'FDX' 'GD' 'GNRC' 'GWW'
#  'HII' 'HON' 'IEX' 'ITW' 'JBHT' 'KSU' 'LHX' 'LMT' 'MMM' 'NOC' 'NSC' 'ODFL'
#  'PH' 'ROK' 'ROP' 'SNA' 'SWK' 'TDG' 'TDY' 'TT' 'UNP' 'UPS' 'URI' 'VRSK'
#  'WM']
# ['AMAT' 'AMD' 'APH' 'CSCO' 'CTSH' 'DXC' 'ENPH' 'FISV' 'GLW' 'HPE' 'HPQ'
#  'INTC' 'JNPR' 'KEYS' 'MU' 'MXIM' 'NLOK' 'NTAP' 'ORCL' 'PAYX' 'PTC' 'STX'
#  'TEL' 'TER' 'TRMB' 'WDC' 'WU']
# ['AMT' 'ARE' 'AVB' 'CCI' 'DLR' 'EQIX' 'ESS' 'EXR' 'MAA' 'PSA' 'SBAC']
# ['APA' 'BKR' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC'
#  'MRO' 'NOV' 'OKE' 'OXY' 'PSX' 'PXD' 'SLB' 'VLO' 'WMB' 'XOM']
# ['APD' 'AVY' 'ECL' 'FMC' 'IFF' 'LIN' 'MLM' 'PPG' 'SHW' 'VMC']
# ['APTV' 'BWA' 'CCL' 'CZR' 'DHI' 'DLTR' 'DRI' 'EBAY' 'EXPE' 'F' 'GM' 'GPC'
#  'GPS' 'GRMN' 'HAS' 'HBI' 'HLT' 'KMX' 'LB' 'LEG' 'LEN' 'LKQ' 'LVS' 'MAR'
#  'MGM' 'MHK' 'NCLH' 'NWL' 'PENN' 'PHM' 'PVH' 'RCL' 'RL' 'ROST' 'SBUX'
#  'TJX' 'TPR' 'UA' 'UAA' 'VFC' 'WYNN']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'FOX' 'FOXA' 'IPG' 'LUMN' 'LYV'
#  'NWS' 'NWSA' 'OMC' 'T' 'TWTR' 'VIAC' 'VZ']
# ['AWK' 'SRE']
# []
# ['BXP' 'CBRE' 'DRE' 'EQR' 'FRT' 'HST' 'IRM' 'KIM' 'O' 'PEAK' 'PLD' 'REG'
#  'SPG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['CHTR' 'DIS' 'EA' 'FB' 'GOOG' 'GOOGL' 'NFLX' 'TMUS' 'TTWO']
# ['CLX' 'COST' 'EL' 'HSY' 'KMB' 'PEP' 'PG' 'SJM' 'STZ' 'WMT']
# ['A' 'ABMD' 'ABT' 'ALGN' 'ALXN' 'AMGN' 'ANTM' 'BDX' 'BIIB' 'BIO' 'CI'
#  'COO' 'CRL' 'DGX' 'DHR' 'DVA' 'DXCM' 'HCA' 'HUM' 'IDXX' 'ILMN' 'IQV'
#  'ISRG' 'JNJ' 'LH' 'LLY' 'MCK' 'MDT' 'MTD' 'PKI' 'REGN' 'RMD' 'STE' 'SYK'
#  'TFX' 'TMO' 'UHS' 'UNH' 'VRTX' 'WAT' 'WST']
# ['AAL' 'ALK' 'AOS' 'CARR' 'CHRW' 'CSX' 'DAL' 'EMR' 'EXPD' 'FAST' 'FBHS'
#  'FTV' 'GE' 'HWM' 'INFO' 'IR' 'JCI' 'LDOS' 'LUV' 'MAS' 'NLSN' 'OTIS'
#  'PCAR' 'PNR' 'PWR' 'RHI' 'ROL' 'RSG' 'RTX' 'TXT' 'UAL' 'WAB' 'XYL']
# ['AAP' 'AMZN' 'APTV' 'AZO' 'BBY' 'BKNG' 'CMG' 'DG' 'DLTR' 'DPZ' 'DRI'
#  'ETSY' 'EXPE' 'GRMN' 'HD' 'LOW' 'MAR' 'MCD' 'MHK' 'NKE' 'NVR' 'ORLY'
#  'POOL' 'ROST' 'TGT' 'TSCO' 'TSLA' 'ULTA' 'WHR']
# ['AAPL' 'ACN' 'ADBE' 'ADI' 'ADP' 'ADSK' 'AKAM' 'ANET' 'ANSS' 'AVGO' 'BR'
#  'CDNS' 'CDW' 'CRM' 'CTXS' 'ENPH' 'FFIV' 'FIS' 'FISV' 'FLT' 'FTNT' 'GPN'
#  'IBM' 'INTU' 'IPGP' 'IT' 'JKHY' 'KEYS' 'KLAC' 'LRCX' 'MA' 'MCHP' 'MPWR'
#  'MSFT' 'MSI' 'NOW' 'NVDA' 'NXPI' 'PAYC' 'PYPL' 'QCOM' 'QRVO' 'SNPS'
#  'SWKS' 'TEL' 'TER' 'TXN' 'TYL' 'V' 'VRSN' 'XLNX']
# ['ABBV' 'ABC' 'BAX' 'BMY' 'BSX' 'CAH' 'CERN' 'CNC' 'CTLT' 'CVS' 'EW'
#  'GILD' 'HOLX' 'HSIC' 'INCY' 'MRK' 'PFE' 'PRGO' 'VTRS' 'XRAY']
# ['ADM' 'CAG' 'CHD' 'CL' 'CPB' 'GIS' 'HRL' 'K' 'KHC' 'KO' 'KR' 'LW' 'MDLZ'
#  'MKC' 'MNST' 'MO' 'PM' 'SYY' 'TAP' 'TSN' 'WBA']
# ['AEE' 'AEP' 'AES' 'ATO' 'CMS' 'CNP' 'D' 'DUK' 'ED' 'EIX' 'ES' 'EVRG'
#  'EXC' 'FE' 'LNT' 'NEE' 'NI' 'NRG' 'PEG' 'PNW' 'PPL' 'SO' 'WEC' 'XEL']
# ['AFL' 'AIG' 'ALL' 'BAC' 'BEN' 'BK' 'C' 'CBOE' 'CFG' 'CINF' 'CMA' 'COF'
#  'DFS' 'FITB' 'GL' 'HBAN' 'HIG' 'IVZ' 'KEY' 'L' 'LNC' 'MET' 'MS' 'NTRS'
#  'PBCT' 'PFG' 'PGR' 'PRU' 'RF' 'RJF' 'SCHW' 'STT' 'SYF' 'TFC' 'UNM' 'USB'
#  'WFC' 'WRB']
# ['AIZ' 'AJG' 'AMP' 'AON' 'AXP' 'BLK' 'CB' 'CME' 'FRC' 'GS' 'ICE' 'JPM'
#  'MCO' 'MKTX' 'MMC' 'MSCI' 'MTB' 'NDAQ' 'PNC' 'RE' 'SIVB' 'SPGI' 'TROW'
#  'TRV' 'WLTW']
# ['ALB' 'APD' 'AVY' 'CE' 'ECL' 'FMC' 'IFF' 'LIN' 'MLM' 'PKG' 'PPG' 'SHW'
#  'VMC']
# ['ALLE' 'AME' 'BA' 'CAT' 'CMI' 'CPRT' 'CTAS' 'DE' 'DOV' 'EFX' 'ETN' 'FDX'
#  'GD' 'GNRC' 'GWW' 'HII' 'HON' 'IEX' 'ITW' 'J' 'JBHT' 'KSU' 'LHX' 'LMT'
#  'MMM' 'NOC' 'NSC' 'ODFL' 'PH' 'ROK' 'ROP' 'SNA' 'SWK' 'TDG' 'TDY' 'TT'
#  'UNP' 'UPS' 'URI' 'VRSK' 'WM']
# ['AMAT' 'AMD' 'APH' 'CSCO' 'CTSH' 'DXC' 'GLW' 'HPE' 'HPQ' 'INTC' 'JNPR'
#  'MU' 'MXIM' 'NLOK' 'NTAP' 'ORCL' 'PAYX' 'PTC' 'STX' 'TRMB' 'WDC' 'WU']
# ['AMCR' 'BLL' 'CF' 'CTVA' 'DD' 'DOW' 'EMN' 'FCX' 'IP' 'LYB' 'MOS' 'NEM'
#  'NUE' 'SEE' 'WRK']
# ['AMT' 'ARE' 'AVB' 'CCI' 'DLR' 'EQIX' 'ESS' 'EXR' 'MAA' 'PSA' 'SBAC']
# ['APA' 'BKR' 'COG' 'COP' 'CVX' 'DVN' 'EOG' 'FANG' 'HAL' 'HES' 'KMI' 'MPC'
#  'MRO' 'NOV' 'OKE' 'OXY' 'PSX' 'PXD' 'SLB' 'VLO' 'WMB' 'XOM']
# ['ATVI' 'CMCSA' 'DISCA' 'DISCK' 'DISH' 'FOX' 'FOXA' 'IPG' 'LUMN' 'LYV'
#  'NWS' 'NWSA' 'OMC' 'T' 'TWTR' 'VIAC' 'VZ']
# ['AWK' 'DTE' 'ETR' 'SRE']
# []
# ['BWA' 'CCL' 'CZR' 'DHI' 'EBAY' 'F' 'GM' 'GPC' 'GPS' 'HAS' 'HBI' 'HLT'
#  'KMX' 'LB' 'LEG' 'LEN' 'LKQ' 'LVS' 'MGM' 'NCLH' 'NWL' 'PENN' 'PHM' 'PVH'
#  'RCL' 'RL' 'SBUX' 'TJX' 'TPR' 'UA' 'UAA' 'VFC' 'WYNN']
# ['BXP' 'CBRE' 'DRE' 'EQR' 'FRT' 'HST' 'IRM' 'KIM' 'O' 'PEAK' 'PLD' 'REG'
#  'SPG' 'UDR' 'VNO' 'VTR' 'WELL' 'WY']
# ['CHTR' 'DIS' 'EA' 'FB' 'GOOG' 'GOOGL' 'NFLX' 'TMUS' 'TTWO']
# ['CLX' 'COST' 'EL' 'HSY' 'KMB' 'PEP' 'PG' 'SJM' 'STZ' 'WMT']
